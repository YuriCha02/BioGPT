# %% [markdown]
# <a href="https://colab.research.google.com/github/YuriCha02/BioGPT/blob/main/Part1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 확인하세요!
#
# ### 제출 전에 모든 코드가 순차적으로 잘 작동하는지 확인하세요.
# - **커널을 다시 시작**한 다음(메뉴바에서 런타임$\rightarrow$런타임 다시 시작 선택) **모든 셀을 실행**해 보세요(메뉴바에서 런타임$\rightarrow$모두 실행 선택).
#
# ### 지정 셀의 지정 영역에서만 코드를 작성했는지 확인하세요.
# - `YOUR CODE HERE`이 적혀 있는 셀에 대한 코드만 채점에 반영됩니다.
# - `YOUR CODE HERE` ~ `YOUR CODE ENDS HERE` 사이에 본인의 코드를 작성하세요.
# - 지정 셀 이외에 본인이 코드 실행 결과를 확인하기 위한 용도로 셀을 추가해도 됩니다.
#     - **제출 시 지정 셀에서는 정답 이외에 결과 확인을 위한 코드 등은 제거하고 제출해 주세요!**
#     - **기존 셀을 삭제하지 마세요! 채점에 불이익이 있을 수 있습니다.**
#
# ### 제출 방법
# - 시간 내에 문제를 풀고, 본인의 github repo에 push 하세요.
#     - **디렉토리 구조가 변하면 안 됩니다.** `codestates/ds-sc2xx`와 디렉토리 구조가 동일해야 합니다. 답안 파일의 이름을 변경하지 않았는지, 기존에 없던 폴더가 추가되지 않았는지 등을 확인하세요.
#     - **코드스테이츠 가입 시 연동한 github 계정을 사용해야 합니다.**
#     - **branch를 변경하여 작업하지 마세요.**
#         - `master` branch에의 제출 사항에 대해서만 평가합니다.
#         - 본인의 github repo `master` branch에 제출이 잘 되어 있는지 확인하세요.

# %% [markdown]
# ---

# %% [markdown]
# # SC22x
#
# ### 코비 브라이언트의 슛 성공 여부 예측해보기
#
# 이번 스프린트 챌린지에서는 故 코비 브라이언트 선수의 NBA 필드 골 시도들이 담긴 데이터셋을 다룹니다 (1996년 11월 3일부터 2016년 4월 13일까지의 정규 시즌과 플레이오프 시즌 기록).
#
# 여러분은 각 슛의 성공 여부를 슈팅의 대한 정보, 게임에 대한 정보를 통해서 예측해야 합니다. 이것은 상당히 어려운 예측입니다. 해당 데이터셋은 [NBA API]((https://github.com/swar/nba_api) 파이썬 라이브러리를 통해 수집 됐습니다.

# %%
import sys
import warnings

# !pip3 install xgboost
# !pip install scikit-learn==1.1.3

if "google.colab" in sys.modules:
    ## Colab에서 실행하는 경우 필요한 라이브러리를 미리 설치합니다.
    # !pip install category_encoders==2.*
    # !pip install pandas-profiling==2.*

warnings.filterwarnings("ignore")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.9/dist-packages (1.7.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from xgboost) (1.10.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==1.1.3
#   Downloading scikit_learn-1.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.3) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.3) (1.1.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.3) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.3) (1.10.1)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed scikit-learn-1.1.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting category_encoders==2.*
#   Downloading category_encoders-2.6.0-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 KB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from category_encoders==2.*) (0.13.5)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.9/dist-packages (from category_encoders==2.*) (1.4.4)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from category_encoders==2.*) (1.22.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from category_encoders==2.*) (1.10.1)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.9/dist-packages (from category_encoders==2.*) (0.5.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.9/dist-packages (from category_encoders==2.*) (1.1.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.5->category_encoders==2.*) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.5->category_encoders==2.*) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.1->category_encoders==2.*) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.0->category_encoders==2.*) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.0->category_encoders==2.*) (1.1.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.9.0->category_encoders==2.*) (23.0)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas-profiling==2.*
#   Downloading pandas_profiling-2.13.0-py2.py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 KB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: htmlmin>=0.1.12 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (0.1.12)
# Requirement already satisfied: phik>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (0.12.3)
# Requirement already satisfied: matplotlib>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (3.7.1)
# Requirement already satisfied: seaborn>=0.10.1 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (0.12.2)
# Collecting confuse>=1.0.0
#   Downloading confuse-2.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (1.22.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (1.10.1)
# Collecting visions[type_image_path]==0.7.1
#   Downloading visions-0.7.1-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 KB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: tangled-up-in-unicode>=0.0.6 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (0.2.0)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (22.2.0)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (2.27.1)
# Requirement already satisfied: missingno>=0.4.2 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (0.5.2)
# Requirement already satisfied: jinja2>=2.11.1 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (3.1.2)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (1.4.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (1.1.1)
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.9/dist-packages (from pandas-profiling==2.*) (4.65.0)
# Collecting multimethod==1.4
#   Downloading multimethod-1.4-py2.py3-none-any.whl (7.3 kB)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.1->pandas-profiling==2.*) (3.0)
# Collecting bottleneck
#   Downloading Bottleneck-1.3.7-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (353 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.1/353.1 KB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: imagehash in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.1->pandas-profiling==2.*) (4.3.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.1->pandas-profiling==2.*) (8.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from confuse>=1.0.0->pandas-profiling==2.*) (6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2>=2.11.1->pandas-profiling==2.*) (2.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.0->pandas-profiling==2.*) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.0->pandas-profiling==2.*) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.0->pandas-profiling==2.*) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.0->pandas-profiling==2.*) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.0->pandas-profiling==2.*) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.0->pandas-profiling==2.*) (4.39.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.0->pandas-profiling==2.*) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.0->pandas-profiling==2.*) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==2.*) (2022.7.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.24.0->pandas-profiling==2.*) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.24.0->pandas-profiling==2.*) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.24.0->pandas-profiling==2.*) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.24.0->pandas-profiling==2.*) (1.26.15)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.0->pandas-profiling==2.*) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling==2.*) (1.16.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.9/dist-packages (from imagehash->visions[type_image_path]==0.7.1->pandas-profiling==2.*) (1.4.1)
# Installing collected packages: multimethod, confuse, bottleneck, visions, pandas-profiling
#   Attempting uninstall: multimethod
#     Found existing installation: multimethod 1.9.1
#     Uninstalling multimethod-1.9.1:
#       Successfully uninstalled multimethod-1.9.1
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
#   Attempting uninstall: pandas-profiling
#     Found existing installation: pandas-profiling 3.2.0
#     Uninstalling pandas-profiling-3.2.0:
#       Successfully uninstalled pandas-profiling-3.2.0
# Successfully installed bottleneck-1.3.7 confuse-2.0.0 multimethod-1.4 pandas-profiling-2.13.0 visions-0.7.1

# %%
# 데이터셋을 불러옵니다
import pandas as pd

url = "https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/nba/nba_kobe_bryant.csv"
df = pd.read_csv(url)

# 데이터셋이 잘 불러졌는지 확인합니다
assert df.shape == (30697, 19)

# %%
df.head()
# Out:
#     game_id  game_event_id  player_name  period  minutes_remaining  \
# 0  29600027            102  Kobe Bryant       1                  0
# 1  29600031            127  Kobe Bryant       2                 10
# 2  29600044            124  Kobe Bryant       2                  8
# 3  29600044            144  Kobe Bryant       2                  6
# 4  29600044            151  Kobe Bryant       2                  5
#
#    seconds_remaining action_type       shot_type        shot_zone_basic  \
# 0                 42   Jump Shot  2PT Field Goal              Mid-Range
# 1                  8   Jump Shot  2PT Field Goal              Mid-Range
# 2                 37   Jump Shot  3PT Field Goal              Mid-Range
# 3                 34   Jump Shot  3PT Field Goal        Restricted Area
# 4                 27   Jump Shot  2PT Field Goal  In The Paint (Non-RA)
#
#          shot_zone_area  shot_zone_range  shot_distance  loc_x  loc_y  \
# 0  Left Side Center(LC)        16-24 ft.             18   -140    116
# 1  Left Side Center(LC)        16-24 ft.             16   -131     97
# 2  Left Side Center(LC)        16-24 ft.             23   -142    181
# 3             Center(C)  Less Than 8 ft.              0      0      0
# 4             Center(C)         8-16 ft.             13    -10    138
#
#    shot_made_flag   game_date  htm  vtm     season_type
# 0               0  1996-11-03  LAL  MIN  Regular Season
# 1               0  1996-11-05  NYK  LAL  Regular Season
# 2               1  1996-11-06  CHH  LAL  Regular Season
# 3               0  1996-11-06  CHH  LAL  Regular Season
# 4               1  1996-11-06  CHH  LAL  Regular Season

# %%
# 살펴보기
df.isnull().sum()
# Out:
# game_id              0
# game_event_id        0
# player_name          0
# period               0
# minutes_remaining    0
# seconds_remaining    0
# action_type          0
# shot_type            0
# shot_zone_basic      0
# shot_zone_area       0
# shot_zone_range      0
# shot_distance        0
# loc_x                0
# loc_y                0
# shot_made_flag       0
# game_date            0
# htm                  0
# vtm                  0
# season_type          0
# dtype: int64

# %% [markdown]
# # Part 1 - Data Preprocessing

# %% [markdown]
# ## 1.1 분류를 위한 베이스라인 정확도를 계산하는 `calculate_baseline_score` 함수를 작성하세요.
# - 예측해야 하는 target은 `shot_made_flag` 입니다.
# - 전체 데이터를 써서 baseline **accuracy score**를 계산하세요.
# - 최빈 클래스를 사용하는 baseline을 가정하세요.

# %%
def calculate_baseline_score(df):
    baseline_score = 0

    # YOUR CODE HERE
    from sklearn.metrics import accuracy_score
    target = 'shot_made_flag'

    base = df[target].mode()[0]
    baseline = len(df[target]) * [base]
    baseline_score = accuracy_score(df[target], baseline)
    # YOUR CODE ENDS HERE

    return baseline_score

# %%
baseline_accuracy_score = calculate_baseline_score(df)

# %%
print("baseline accuracy score:", baseline_accuracy_score)
# Out:
# baseline accuracy score: 0.5526924455158485

# %% [markdown]
# ## 1.2 데이터셋을 아래의 기준을 사용해서 train/test 셋으로 나누는 `split_data` 함수를 작성하세요.
#
# - `test set`: **2014-15** ~ **2015-16** 시즌
# - NBA 시즌은 **10월**에 시작해서 **6월**에 종료합니다.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30697 entries, 0 to 30696
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_id            30697 non-null  int64
#  1   game_event_id      30697 non-null  int64
#  2   player_name        30697 non-null  object
#  3   period             30697 non-null  int64
#  4   minutes_remaining  30697 non-null  int64
#  5   seconds_remaining  30697 non-null  int64
#  6   action_type        30697 non-null  object
#  7   shot_type          30697 non-null  object
#  8   shot_zone_basic    30697 non-null  object
#  9   shot_zone_area     30697 non-null  object
#  10  shot_zone_range    30697 non-null  object
#  11  shot_distance      30697 non-null  int64
#  12  loc_x              30697 non-null  int64
#  13  loc_y              30697 non-null  int64
#  14  shot_made_flag     30697 non-null  int64
#  15  game_date          30697 non-null  object
#  16  htm                30697 non-null  object
#  17  vtm                30697 non-null  object
#  18  season_type        30697 non-null  object
# dtypes: int64(9), object(10)
# memory usage: 4.4+ MB

# %%
def split_data(df):
    train = None
    test = None

    # YOUR CODE HERE
    from datetime import datetime
    df['game_date'] = pd.to_datetime(df['game_date'])
    mask = ((df['game_date'] >= '2014-10-01') & (df['game_date'] <= '2015-06-30')) | ((df['game_date'] >= '2015-10-01') & (df['game_date'] <= '2016-06-30'))
    test = df.loc[mask, :].astype(str)
    train = df.drop(test.index, axis = 0).astype(str)
    
    # YOUR CODE ENDS HERE

    return train, test

# %%
train, test = split_data(df.copy())

# %%
train
# Out:
#         game_id game_event_id  player_name period minutes_remaining  \
# 0      29600027           102  Kobe Bryant      1                 0
# 1      29600031           127  Kobe Bryant      2                10
# 2      29600044           124  Kobe Bryant      2                 8
# 3      29600044           144  Kobe Bryant      2                 6
# 4      29600044           151  Kobe Bryant      2                 5
# ...         ...           ...          ...    ...               ...
# 28866  21300366            34  Kobe Bryant      1                 7
# 28867  21300366            16  Kobe Bryant      1                10
# 28868  21300366             5  Kobe Bryant      1                11
# 28869  21300366             2  Kobe Bryant      1                11
# 28870  21300366            73  Kobe Bryant      1                 4
#
#       seconds_remaining               action_type       shot_type  \
# 0                    42                 Jump Shot  2PT Field Goal
# 1                     8                 Jump Shot  2PT Field Goal
# 2                    37                 Jump Shot  3PT Field Goal
# 3                    34                 Jump Shot  3PT Field Goal
# 4                    27                 Jump Shot  2PT Field Goal
# ...                 ...                       ...             ...
# 28866                45                Layup Shot  2PT Field Goal
# 28867                 9  Turnaround Fadeaway shot  2PT Field Goal
# 28868                13                Layup Shot  2PT Field Goal
# 28869                41                 Jump Shot  2PT Field Goal
# 28870                34                Layup Shot  2PT Field Goal
#
#              shot_zone_basic        shot_zone_area  shot_zone_range  \
# 0                  Mid-Range  Left Side Center(LC)        16-24 ft.
# 1                  Mid-Range  Left Side Center(LC)        16-24 ft.
# 2                  Mid-Range  Left Side Center(LC)        16-24 ft.
# 3            Restricted Area             Center(C)  Less Than 8 ft.
# 4      In The Paint (Non-RA)             Center(C)         8-16 ft.
# ...                      ...                   ...              ...
# 28866        Restricted Area             Center(C)  Less Than 8 ft.
# 28867              Mid-Range         Right Side(R)         8-16 ft.
# 28868        Restricted Area             Center(C)  Less Than 8 ft.
# 28869              Mid-Range  Left Side Center(LC)        16-24 ft.
# 28870        Restricted Area             Center(C)  Less Than 8 ft.
#
#       shot_distance loc_x loc_y shot_made_flag   game_date  htm  vtm  \
# 0                18  -140   116              0  1996-11-03  LAL  MIN
# 1                16  -131    97              0  1996-11-05  NYK  LAL
# 2                23  -142   181              1  1996-11-06  CHH  LAL
# 3                 0     0     0              0  1996-11-06  CHH  LAL
# 4                13   -10   138              1  1996-11-06  CHH  LAL
# ...             ...   ...   ...            ...         ...  ...  ...
# 28866             0     2     0              1  2013-12-17  MEM  LAL
# 28867            11   106    50              1  2013-12-17  MEM  LAL
# 28868             0     0     1              0  2013-12-17  MEM  LAL
# 28869            22  -130   183              0  2013-12-17  MEM  LAL
# 28870             0     0    -3              0  2013-12-17  MEM  LAL
#
#           season_type
# 0      Regular Season
# 1      Regular Season
# 2      Regular Season
# 3      Regular Season
# 4      Regular Season
# ...               ...
# 28866  Regular Season
# 28867  Regular Season
# 28868  Regular Season
# 28869  Regular Season
# 28870  Regular Season
#
# [28871 rows x 19 columns]

# %% [markdown]
# ## 1.3 새로운 feature를 만드는 `feature_engineering` 함수를 작성하세요.
#
# - 새로운 이름을 갖는 최소 2개 이상의 새로운 feature를 만드세요. 아래의 리스트를 사용하셔도 되고 스스로의 아이디어로 만들어 주셔도 괜찮습니다.
#     - **Homecourt Advantage**: 홈 팀(`htm`)이 Los Angeles Lakers (`LAL`)인지 여부
#     - **Opponent**: LA Lakers를 상대하는 팀을 나타내는 feature
#     - **Seconds remaining in the period**: 피리어드에 남은 총 시간 (분과 초를 합칩니다)
#     - **Seconds remaining in the game**: 게임에 남은 총 시간 (피리어드와 초를 합칩니다). 농구에서 게임은 총 4개의 피리어드로 이루어져 있습니다 (각 12분)
#     - **Made previous shot**: 코비 브라이언트의 예전 슛이 성공했는지 여부
# - 학습에 사용하지 않는 특성은 drop하세요.

# %%
def feature_engineering(df):
    df_tmp = df.copy()

    # YOUR CODE HERE
    df_tmp['Homecourt Advantage'] = df_tmp['htm'].str.contains('LAL')
    df_tmp['shot_made_flag'] = df_tmp['shot_made_flag'].astype('int64')
    df_tmp['minutes_remaining'] = df_tmp['minutes_remaining'].astype('int64')
    df_tmp['seconds_remaining'] = df_tmp['seconds_remaining'].astype('int64')
    df_tmp['Seconds remaining in the period'] = (df_tmp['minutes_remaining']*60 + df_tmp['seconds_remaining'])
    # YOUR CODE ENDS HERE

    return df_tmp

# %%
train_processed = feature_engineering(train)
test_processed = feature_engineering(test)

# %%
train_processed.head()
# Out:
#     game_id game_event_id  player_name period  minutes_remaining  \
# 0  29600027           102  Kobe Bryant      1                  0
# 1  29600031           127  Kobe Bryant      2                 10
# 2  29600044           124  Kobe Bryant      2                  8
# 3  29600044           144  Kobe Bryant      2                  6
# 4  29600044           151  Kobe Bryant      2                  5
#
#    seconds_remaining action_type       shot_type        shot_zone_basic  \
# 0                 42   Jump Shot  2PT Field Goal              Mid-Range
# 1                  8   Jump Shot  2PT Field Goal              Mid-Range
# 2                 37   Jump Shot  3PT Field Goal              Mid-Range
# 3                 34   Jump Shot  3PT Field Goal        Restricted Area
# 4                 27   Jump Shot  2PT Field Goal  In The Paint (Non-RA)
#
#          shot_zone_area  ... shot_distance loc_x loc_y shot_made_flag  \
# 0  Left Side Center(LC)  ...            18  -140   116              0
# 1  Left Side Center(LC)  ...            16  -131    97              0
# 2  Left Side Center(LC)  ...            23  -142   181              1
# 3             Center(C)  ...             0     0     0              0
# 4             Center(C)  ...            13   -10   138              1
#
#     game_date  htm  vtm     season_type Homecourt Advantage  \
# 0  1996-11-03  LAL  MIN  Regular Season                True
# 1  1996-11-05  NYK  LAL  Regular Season               False
# 2  1996-11-06  CHH  LAL  Regular Season               False
# 3  1996-11-06  CHH  LAL  Regular Season               False
# 4  1996-11-06  CHH  LAL  Regular Season               False
#
#    Seconds remaining in the period
# 0                               42
# 1                              608
# 2                              517
# 3                              394
# 4                              327
#
# [5 rows x 21 columns]

# %%
test_processed.head()
# Out:
#         game_id game_event_id  player_name period  minutes_remaining  \
# 28871  21400003            76  Kobe Bryant      1                  6
# 28872  21400003            94  Kobe Bryant      1                  4
# 28873  21400003           413  Kobe Bryant      3                  5
# 28874  21400003           520  Kobe Bryant      4                  9
# 28875  21400003           553  Kobe Bryant      4                  7
#
#        seconds_remaining           action_type       shot_type  \
# 28871                 13             Jump Shot  2PT Field Goal
# 28872                 45             Jump Shot  2PT Field Goal
# 28873                 52  Turnaround Jump Shot  2PT Field Goal
# 28874                 36             Jump Shot  3PT Field Goal
# 28875                 16             Jump Shot  2PT Field Goal
#
#              shot_zone_basic        shot_zone_area  ... shot_distance loc_x  \
# 28871              Mid-Range             Center(C)  ...            20   -54
# 28872  In The Paint (Non-RA)             Center(C)  ...             6   -16
# 28873              Mid-Range         Right Side(R)  ...            18   166
# 28874      Above the Break 3  Left Side Center(LC)  ...            27  -138
# 28875              Mid-Range          Left Side(L)  ...            19  -179
#
#       loc_y shot_made_flag   game_date  htm  vtm     season_type  \
# 28871   201              0  2014-10-28  LAL  HOU  Regular Season
# 28872    63              1  2014-10-28  LAL  HOU  Regular Season
# 28873    78              0  2014-10-28  LAL  HOU  Regular Season
# 28874   241              0  2014-10-28  LAL  HOU  Regular Season
# 28875    88              0  2014-10-28  LAL  HOU  Regular Season
#
#       Homecourt Advantage  Seconds remaining in the period
# 28871                True                              373
# 28872                True                              285
# 28873                True                              352
# 28874                True                              576
# 28875                True                              436
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 1.4 train / test 셋을 features(X)와 target(y)으로 각각 나누는 `divide_data` 함수를 작성하세요.
# - `pd.DataFrame` 형태의 `X`와 `pd.Series` 형태의 `y`를 반환하세요.

# %%
def divide_data(df):
    X = None
    y = None

    # YOUR CODE HERE
    target = 'shot_made_flag'
    X = df.drop(target, axis = 1)
    y= df[target]
    
    # YOUR CODE ENDS HERE

    return X, y

# %%
X_train, y_train = divide_data(train_processed)
X_test, y_test = divide_data(test_processed)

# %%
X_train.shape, X_test.shape
# Out:
# ((28871, 20), (1826, 20))

# %% [markdown]
# # Part 2 - Modeling & Evaluation

# %% [markdown]
# ## 2.1 RandomForest 또는 XGBoost 모델 학습 파이프라인을 생성하고 학습하는 `fit_trees` 함수를 작성하세요.
# - Scikit-learn의 `pipeline`을 활용하여 범주형 feature의 encoder, imputer, 모델을 포함하는 하나의 학습 파이프라인을 구축하세요.
# - 구축한 파이프라인에 대해 `RandomizedSearchCV`를 사용해 CV를 진행하세요.
#     - 적어도 두 개 이상의 하이퍼파라미터에 대해 탐색을 진행하세요.
#     - F1 score를 최대화하는 하이퍼파라미터 조합을 선택하세요.
# - RandomForestClassifier, RandomizedSearchCV 등 랜덤성이 포함되는 방법론에 대해 모두 `random_state=42`로 하세요.
# - cv는 5 이하, n_iter은 10회 이하로 하세요.

# %%
import sklearn
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.impute import SimpleImputer
from category_encoders import OrdinalEncoder

### IMPORT ANY
# YOUR CODE HERE

# YOUR CODE ENDS HERE


def fit_trees(X_train, y_train):
    pipe = None    # pipe = make_pipeline(...)
    clf = None     # clf = RandomizedSearchCV(pipe, ...)

    # YOUR CODE HERE
    pipe = make_pipeline(OrdinalEncoder(handle_missing='return_nan'),
                         SimpleImputer(strategy='most_frequent'),
                         XGBClassifier(objective="binary:logistic", 
                                       eval_metric="aucpr", 
                                       n_estimators=500, 
                                       random_state=42, 
                                       n_jobs=-1,
                                       learning_rate = 0.05
                                       )
                         )
    params = {
         "xgbclassifier__min_child_weight": [1, 3, 5, 7, 9],
        "xgbclassifier__max_depth": [1, 3, 5, 7, 9],
        "xgbclassifier__colsample_bytree": [0.25, 0.5, 0.75, 1],
        "xgbclassifier__reg_lambda": [0, 0.25, 0.5, 0.75, 1],
        "xgbclassifier__scale_pos_weight": [1, 3, 5],
        "xgbclassifier__reg_alpha": [0.1, 0.5, 1, 2, 3, 4, 5, 6, 7],
        "xgbclassifier__gamma": [0, 0.5, 1],
        "xgbclassifier__max_delta_step": [0, 0.5, 1],
        "xgbclassifier__subsample": [0.5, 0.75, 1]
    }

    randomized_search = RandomizedSearchCV(pipe, param_distributions=params, n_iter=10, scoring="accuracy", cv=5, verbose=3, random_state=42)
    clf = randomized_search.fit(X_train, y_train)
    # YOUR CODE ENDS HERE

    return clf

# %%
clf = fit_trees(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [C
# [CV 3/5] END xgbclassifier__colsample_bytree=0.5, xgbclassifier__gamma=0.5, xgbclassifier__max_delta_step=0.5, xgbclassifier__max_depth=5, xgbclassifier__min_child_weight=9, xgbclassifier__reg_alpha=0.1, xgbclassifier__reg_lambda=1, xgbclassifier__scale_pos_weight=5, xgbclassifier__subsample=0.5;, score=0.469 total time=   8.9s
# [CV 4/5] END xgbclassifier__colsample_bytree=0.5, xgbclassifier__gamma=0.5, xgbclassifier__max_delta_step=0.5, xgbclassifier__max_depth=5, xgbclassifier__min_child_weight=9, xgbclassifier__reg_alpha=0.1, xgbclassifier__reg_lambda=1, xgbclassifier__scale_pos_weight=5, xgbclassifier__subsample=0.5;, score=0.482 total time=  10.5s
# [CV 5/5] END xgbclassifier__colsample_bytree=0.5, xgbclassifier__gamma=0.5, xgbclassifier__max_delta_step=0.5, xgbclassifier__max_depth=5, xgbclassifier__min_child_weight=9, xgbclassifier__reg_alpha=0.1, xgbclassifier__reg_lambda=1, xgbclassifier__scale_pos_weight=5, xgbclassifier__subsample=0.5;, score=0.475 total time=  11.1s
# [CV 1/5] END xgbclassifier__colsample_bytree=0.25, xgbclassifier__gamma=1, xgbclassifier__max_delta_step=1, xgbclassifier__max_depth=7, xgbclassifier__min_child_weight=3, xgbclassifier__reg_alpha=0.1, xgbclassifier__reg_lambda=0.5, xgbclassifier__scale_pos_weight=1, xgbclassifier__subsample=0.5;, score=0.664 total time=  11.0s
# [CV 2/5] END xgbclassifier__colsample_bytree=0.25, xgbclassifier__gamma=1, xgbclassifier__max_delta_step=1, xgbclassifier__max_depth=7, xgbclassifier__min_child_weight=3, xgbclassifier__reg_alpha=0.1, xgbclassifier__reg_lambda=0.5, xgbclassifier__scale_pos_weight=1, xgbclassifier__subsample=0.5;, score=0.679 total time=  13.2s
# [CV 3/5] END xgbclassifier__colsample_bytree=0.25, xgbclassifier__gamma=1, xgbclassifier__max_delta_step=1, xgbclassifier__max_depth=7, xgbclassifier__min_child_weight=3, xgbclassifier__reg_alpha=0.1, xgbclassifier__reg_lambda=0.5, xgbclassifier__scale_pos_weight=1, xgbclassifier__subsample=0.5;, score=0.664 total time=  10.8s
# [CV 4/5] END xgbclassifier__colsample_bytree=0.25, xgbclassifier__gamma=1, xgbclassifier__max_delta_step=1, xgbclassifier__max_depth=7, xgbclassifier__min_child_weight=3, xgbclassifier__reg_alpha=0.1, xgbclassifier__reg_lambda=0.5, xgbclassifier__scale_pos_weight=1, xgbclassifier__subsample=0.5;, score=0.666 total time=  10.9s
# [CV 5/5] END xgbclassifier__colsample_bytree=0.25, xgbclassifier__gamma=1, xgbclassifier__max_delta_step=1, xgbclassifier__max_depth=7, xgbclassifier__min_child_weight=3, xgbclassifier__reg_alpha=0.1, xgbclassifier__reg_lambda=0.5, xgbclassifier__scale_pos_weight=1, xgbclassifier__subsample=0.5;, score=0.647 total time=   8.7s

# %%
print("Best CV F1", clf.best_score_)
print("Best CV params", clf.best_params_)
# Out:
# Best CV F1 0.6776004750358752
# Best CV params {'xgbclassifier__subsample': 0.75, 'xgbclassifier__scale_pos_weight': 1, 'xgbclassifier__reg_lambda': 1, 'xgbclassifier__reg_alpha': 5, 'xgbclassifier__min_child_weight': 1, 'xgbclassifier__max_depth': 1, 'xgbclassifier__max_delta_step': 0.5, 'xgbclassifier__gamma': 0.5, 'xgbclassifier__colsample_bytree': 0.5}

# %% [markdown]
# ## 2.2 학습된 모델로부터 feature importance를 계산하는 `get_feature_importances` 함수를 작성하세요.
# - feature_importances 변수에 feature_importances_ 값을 할당하면 됩니다.

# %%
import numpy as np


def get_feature_importances(pipe, feature_names):
    feature_importances = np.zeros(len(feature_names))

    # YOUR CODE HERE
    model = pipe.named_steps['xgbclassifier']
    feature_importances = model.feature_importances_
    # YOUR CODE ENDS HERE

    return sorted(
        list(zip(feature_names, feature_importances)), key=lambda x: x[1], reverse=True
    )

# %%
feature_importances = get_feature_importances(
    clf.best_estimator_, list(X_train.columns)
)

# %%
for name, importance in feature_importances:
    print(f"{name}: {importance:.4f}")
# Out:
# action_type: 0.2278
# shot_zone_basic: 0.1750
# loc_x: 0.1467
# shot_type: 0.0917
# loc_y: 0.0824
# Seconds remaining in the period: 0.0409
# shot_zone_area: 0.0396
# shot_zone_range: 0.0391
# minutes_remaining: 0.0273
# period: 0.0202
# seconds_remaining: 0.0185
# shot_distance: 0.0183
# game_id: 0.0142
# htm: 0.0138
# game_date: 0.0137
# game_event_id: 0.0130
# vtm: 0.0103
# Homecourt Advantage: 0.0075
# player_name: 0.0000
# season_type: 0.0000

# %% [markdown]
# ## 2.3 본인이 만든 모델의 Test 셋에서의 성능을 확인해 보세요.
# - ### test_accuracy > 0.6, test_f1 > 0.5를 만족하면 기본 성능점수를 얻습니다.
# - ###  (도전과제) test_accuracy > 0.68, test_f1 > 0.54를 만족하면 성능점수 만점을 얻습니다.
#   - 도전과제까지 수행해야 스챌 3점을 얻습니다.
#   - 1.3으로 돌아가 다양한 특성 조합을 시도해 보세요.
#     - 그리고 2.2로 돌아와 피쳐 중요도를 계산해 보세요.
#     - 어떤 피쳐의 중요도가 가장 높나요?
#     - 중요도가 낮은 피쳐라도 있는 게 좋을까요?
#   - 2.1로 돌아가 SearchCV에서 다양한 하이퍼파라미터 옵션 조합을 선택해 보세요.
#     - 본인이 선택한 모델에서, 각 하이퍼파라미터가 어떤 의미를 가지나요?
#     - SearchCV가 더 다양한 하이퍼파라미터 조합을 시도하도록 하기 위해 SearchCV의 어떤 옵션을 조정해야 할까요?

# %%
def calculate_score(pipe, X_test, y_test):
    test_accuracy = pipe.score(X_test, y_test)
    test_f1 = f1_score(y_test, pipe.predict(X_test))
    return test_accuracy, test_f1

# %%
test_accuracy, test_f1 = calculate_score(clf.best_estimator_, X_test, y_test)

# %%
print("test accuracy: ", test_accuracy)
print("test F1:", test_f1)
# Out:
# test accuracy:  0.6757940854326396
# test F1: 0.5396578538102643

# %%
print("test accuracy > 0.68?: ", test_accuracy > 0.68)
print("test F1 > 0.54?:", test_f1 > 0.54)
# Out:
# test accuracy > 0.68?:  False
# test F1 > 0.54?: False

# %% [markdown]
# ---

# %% [markdown]
# # 수고하셨습니다!
